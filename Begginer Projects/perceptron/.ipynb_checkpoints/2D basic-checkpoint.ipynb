# %%
import matplotlib.pyplot as plt
import numpy as np

# set 1 (blue)
x1_points = [-10,-8,-6,-3,-1, -1, -4, 1, 2, 1]
y1_points = [-2,7,3,-4,4, 0, 3, -4, -5, -3]

# set 2 (red)
x2_points = [-2,-1,2,3,4,5,6,7,8,9,]
y2_points = [6,4,6,2,0,-1,-4,2,-5,4]

# perceptron estimation
t = 1
c = 0

def graph(a,b):
    plt.axvline(x=0)
    plt.axhline(y=0)
    
    rise = [(i/t) for i in range(-10,11)]  # add c to rise for an increase in x-int
    run = [i + c for i in range(-10,11)]   # add c to run for an increase in y-int
    
    plt.plot(rise, run)


    plt.plot(x1_points, y1_points, "o", color="blue")
    plt.plot(x2_points, y2_points, "o", color="red")

    
    plt.show()
    
graph(t,c)

# %%
# Perceptron

initial = (0,1,0.5)

t = 1
c = 0

def perceptron(w):
    rate = 1
    n = 0
    x = (1,x1_points[n], y1_points[n])
    t = np.dot(w,x)
    
    print(t)
    return t

t = perceptron(initial)


graph(t, c)
# Out:
# -11.0

# %%
def getStatus(g,h):
    
    values_below = []
    values_above = []
    
    for i in range(len(x1_points)):
        print(i, y1_points[i])
        if ((g * i) + h) < y1_points[i]:
            values_above.append([i, y1_points[i]])
        elif ((g * i) + h) > y1_points[i]:
            values_below.append([i, y1_points[i]])
    for i, j in zip(x, y):
        plt.text(i, j+0.5, '({}, {})'.format(i, j))
    
    
    print(values_below)
    print("\n")
    print(values_above)
   
    
getStatus(t,c)


# This isnt right

# TO DO

# Match up values such that we get the points below (the numbers below are not the points)
# Check if the values (in both sets (red and blue)) are below or above the line 
# Use these above and below lists to run perceptron model on
# Out:
# 0 -2
# 1 7
# 2 3
# 3 -4
# 4 4
# 5 0
# 6 3
# 7 -4
# 8 -5
# 9 -3
# [[0, -2]]
#
#
# [[1, 7], [2, 3], [3, -4], [4, 4], [5, 0], [6, 3], [7, -4], [8, -5], [9, -3]]
