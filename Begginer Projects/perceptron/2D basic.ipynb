# %%
import matplotlib.pyplot as plt
import numpy as np

# set 1
x1_points = [-10,-8,-6,-3,-1, 0, -4, 1, 2, 1]
y1_points = [-2,7,3,-4,4, 0, 3, -4, -5, -3]

# set 2 
x2_points = [-2,-1,2,3,4,5,6,7,8,9,]
y2_points = [6,4,6,2,0,-1,-4,2,-5,4]

# perceptron estimation
t = -2
c =0

def graph(a,b):
    plt.axvline(x=0)
    plt.axhline(y=0)
    
    rise = [(i/t) + c for i in range(-10,11)]
    run = [i for i in range(-10,11)]
    
    plt.plot(rise, run)


    plt.plot(x1_points, y1_points, "o", color="blue")
    plt.plot(x2_points, y2_points, "o", color="red")

    
    plt.show()
    
graph(t,c)

# %%
# Perceptron

initial = (0,1,0.5)

t = -2
c = 0

def perceptron(w):
    rate = 1
    n = 0
    x = (1,x1_points[n], y1_points[n])
    
    print(np.dot(w,x))
    
    return np.dot(w, x)
    
"""
def update(z):
    print("last omega = " + perceptron(initial))
    
    w = perceptron(initial) + rate*d*
    
    return w
    
"""



output = perceptron(initial)  
print(output)
    
print(t,'\n',c)
    
graph(1,1)
# Out:
# -11.0
# -11.0
# -2
#  0

# %%
def getStatus(g,h):
    
    values_below = []
    values_above = []
    
    for i in range(len(x1_points)):
        print(i, y1_points[i])
        if ((g * i) + h) < y1_points[i]:
            values_above.append([i, y1_points[i]])
        elif ((g * i) + h) > y1_points[i]:
            values_below.append([i, y1_points[i]])
    
    """
    print(values_below)
    print("\n")
    print(values_above)
    """
    
getStatus(t,c)


# This isnt right

# TO DO

# Match up values such that we get the points below (the numbers below are not the points)
# Check if the values (in both sets (red and blue)) are below or above the line 
# Use these above and below lists to run perceptron model on
# Out:
# 0 -2
# 1 7
# 2 3
# 3 -4
# 4 4
# 5 0
# 6 3
# 7 -4
# 8 -5
# 9 -3
